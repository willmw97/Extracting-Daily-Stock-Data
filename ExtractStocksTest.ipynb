# %% [markdown]
# This an example of extracting stock data from Yahoo finance. The main goal of this project to develop a database that will contain all stocks.

# %%
import pandas as pd
import time
import random
import yfinance as yf
import os
import warnings;
from datetime import date
from dateutil.relativedelta import relativedelta
warnings.filterwarnings("ignore");
yf.pdr_override()

# %% [markdown]
# As an example I test one company and retrieve the last 5 years of stock data.

# %%
TICKER = 'AAPL'
begin = '2015-01-01'
curr = '2020-01-01'

# %%
stock = yf.download(TICKER, start = begin, end = curr)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
stock
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.941502  212818400
# 2015-01-05  27.072500  27.162500  26.352501  26.562500  24.238857  257142000
# 2015-01-06  26.635000  26.857500  26.157499  26.565001  24.241146  263188400
# 2015-01-07  26.799999  27.049999  26.674999  26.937500  24.581060  160423600
# 2015-01-08  27.307501  28.037500  27.174999  27.972500  25.525522  237458000
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-24  71.172501  71.222504  70.730003  71.067497  70.580566   48478800
# 2019-12-26  71.205002  72.495003  71.175003  72.477501  71.980911   93121200
# 2019-12-27  72.779999  73.492500  72.029999  72.449997  71.953598  146266000
# 2019-12-30  72.364998  73.172501  71.305000  72.879997  72.380653  144114400
# 2019-12-31  72.482498  73.419998  72.379997  73.412498  72.909500  100805600
#
# [1258 rows x 6 columns]

# %% [markdown]
# For our database we want to mark what company does each company belong to so we append the ticker symbol.

# %%
stock['ticker'] = TICKER

# %%
stock
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2015-01-02  27.847500  27.860001  26.837500  27.332500  24.941502  212818400
# 2015-01-05  27.072500  27.162500  26.352501  26.562500  24.238857  257142000
# 2015-01-06  26.635000  26.857500  26.157499  26.565001  24.241146  263188400
# 2015-01-07  26.799999  27.049999  26.674999  26.937500  24.581060  160423600
# 2015-01-08  27.307501  28.037500  27.174999  27.972500  25.525522  237458000
# ...               ...        ...        ...        ...        ...        ...
# 2019-12-24  71.172501  71.222504  70.730003  71.067497  70.580566   48478800
# 2019-12-26  71.205002  72.495003  71.175003  72.477501  71.980911   93121200
# 2019-12-27  72.779999  73.492500  72.029999  72.449997  71.953598  146266000
# 2019-12-30  72.364998  73.172501  71.305000  72.879997  72.380653  144114400
# 2019-12-31  72.482498  73.419998  72.379997  73.412498  72.909500  100805600
#
#            ticker
# Date
# ...

# %% [markdown]
# We then create the header names for our database that will start.

# %%
column_names = ["Open", "High", "Low", "Close", "Adj Close", "Volume", "Ticker"]

database = pd.DataFrame(columns = column_names)

# %%
database
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, Ticker]
# Index: []

# %% [markdown]
# We load our database file then, which is a list of the stock tickers we want.

# %%
df = pd.read_csv('Russell-3000.csv')

# %%
df
# Out:
#      Ticker
# 0         A
# 1        AA
# 2       AAC
# 3       AAL
# 4       AAN
# ...     ...
# 2997   ZNGA
# 2998   ZOES
# 2999    ZTS
# 3000   ZUMZ
# 3001   ZYNE
#
# [3002 rows x 1 columns]

# %% [markdown]
# We assign the dates we want our stocks to look at.

# %%
begin = '2015-01-01'
curr = '2020-01-01'

# %%
database
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume, Ticker]
# Index: []

# %%
for ind in df.index:
    try:
        TICKER = df['Ticker'][ind]
        company = yf.download(TICKER, start = begin, end = curr)
        company['Ticker'] = TICKER
        database = database.append(company)
    except ConnectionRefusedError:#this is meant to retry the connection to yahoo finance after we connected already
        time.sleep(30)
        #continue
    except IndexError:
        pass
        #continue
    except:
        continue
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAC: No data found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...

# %%
database
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# 2015-01-02  41.180000  41.310001  40.369999  40.560001  38.473145  1529200
# 2015-01-05  40.320000  40.459999  39.700001  39.799999  37.752251  2041800
# 2015-01-06  39.810001  40.020000  39.020000  39.180000  37.164139  2080600
# 2015-01-07  39.520000  39.810001  39.290001  39.700001  37.657402  3359700
# 2015-01-08  40.240002  40.980000  40.180000  40.889999  38.786182  2116300
# ...               ...        ...        ...        ...        ...      ...
# 2019-12-24   6.050000   6.100000   5.820000   6.000000   6.000000   401100
# 2019-12-26   5.950000   5.977000   5.750000   5.870000   5.870000   517100
# 2019-12-27   5.790000   5.830000   5.500000   5.760000   5.760000   783700
# 2019-12-30   5.700000   5.730000   5.510000   5.640000   5.640000   553300
# 2019-12-31   5.780000   6.140000   5.650000   6.040000   6.040000   949900
#
#            Ticker
# 2015-01-02      A
# 2015-01-05      A
# ...

# %%
database['Date'] = database.index

# %%
database
# Out:
#                  Open       High        Low      Close  Adj Close   Volume  \
# 2015-01-02  41.180000  41.310001  40.369999  40.560001  38.473145  1529200
# 2015-01-05  40.320000  40.459999  39.700001  39.799999  37.752251  2041800
# 2015-01-06  39.810001  40.020000  39.020000  39.180000  37.164139  2080600
# 2015-01-07  39.520000  39.810001  39.290001  39.700001  37.657402  3359700
# 2015-01-08  40.240002  40.980000  40.180000  40.889999  38.786182  2116300
# ...               ...        ...        ...        ...        ...      ...
# 2019-12-24   6.050000   6.100000   5.820000   6.000000   6.000000   401100
# 2019-12-26   5.950000   5.977000   5.750000   5.870000   5.870000   517100
# 2019-12-27   5.790000   5.830000   5.500000   5.760000   5.760000   783700
# 2019-12-30   5.700000   5.730000   5.510000   5.640000   5.640000   553300
# 2019-12-31   5.780000   6.140000   5.650000   6.040000   6.040000   949900
#
#            Ticker       Date
# 2015-01-02      A 2015-01-02
# ...

# %% [markdown]
# At this point we can save our database to a csv or directly to a database.

# %%
database.to_csv('Russell-3000-Database.csv',index = False)
